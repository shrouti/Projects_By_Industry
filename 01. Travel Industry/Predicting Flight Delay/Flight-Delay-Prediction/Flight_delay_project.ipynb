# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
col_names = ['Month', 'DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'FlightNum', 'Origin', 'Dest', 'DepTime', 'DepDelay', 'TaxiOut', 'WheelsOff', 'WheelsOn', 'TaxiIn', 'ArrTime', 'ArrDelay', 'Cancelled', 'Diverted', 'AirTime', 'Flights', 'Distance', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay', 'DivAirportLandings']

# %%
file_list = ['../On_Time_On_Time_Performance_2017_1.csv', '../On_Time_On_Time_Performance_2017_2.csv', '../On_Time_On_Time_Performance_2017_3.csv', '../On_Time_On_Time_Performance_2017_4.csv', '../On_Time_On_Time_Performance_2017_5.csv', '../On_Time_On_Time_Performance_2017_6.csv', '../On_Time_On_Time_Performance_2017_7.csv', '../On_Time_On_Time_Performance_2017_8.csv', '../On_Time_On_Time_Performance_2017_9.csv', '../On_Time_On_Time_Performance_2017_10.csv', '../On_Time_On_Time_Performance_2017_11.csv', '../On_Time_On_Time_Performance_2017_12.csv']

# %%
#Get Dataframes of all 2017 Months and merge them 
df1 = pd.read_csv(file_list[0], usecols=col_names)[col_names]

# %%
df2 = pd.read_csv(file_list[1], usecols=col_names)[col_names]
df3 = pd.read_csv(file_list[2], usecols=col_names)[col_names]
df4 = pd.read_csv(file_list[3], usecols=col_names)[col_names]
df5 = pd.read_csv(file_list[4], usecols=col_names)[col_names]
df6 = pd.read_csv(file_list[5], usecols=col_names)[col_names]
df7 = pd.read_csv(file_list[6], usecols=col_names)[col_names]
df8 = pd.read_csv(file_list[7], usecols=col_names)[col_names]
df9 = pd.read_csv(file_list[8], usecols=col_names)[col_names]
df10 = pd.read_csv(file_list[9], usecols=col_names)[col_names]
df11 = pd.read_csv(file_list[10], usecols=col_names)[col_names]
df12 = pd.read_csv(file_list[11], usecols=col_names)[col_names]

# %%
frame = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]
merged_df = pd.concat(frame, axis = 0)

# %%
merged_df.head()
# Out:
#    Month  DayofMonth  DayOfWeek UniqueCarrier  FlightNum Origin Dest  DepTime  \
# 0      1          17          2            AA        494    CLT  PHX   1616.0
# 1      1          18          3            AA        494    CLT  PHX   1614.0
# 2      1          19          4            AA        494    CLT  PHX   1611.0
# 3      1          20          5            AA        494    CLT  PHX   1656.0
# 4      1          21          6            AA        494    CLT  PHX   1632.0
#
#    DepDelay  TaxiOut         ...          Diverted  AirTime  Flights  \
# 0      -3.0     17.0         ...               0.0    244.0      1.0
# 1      -5.0     13.0         ...               0.0    228.0      1.0
# 2      -8.0     17.0         ...               0.0    236.0      1.0
# 3      37.0     18.0         ...               0.0    252.0      1.0
# 4      13.0     17.0         ...               0.0    245.0      1.0
#
#    Distance  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0    1773.0           NaN           NaN       NaN            NaN
# 1    1773.0           NaN           NaN       NaN            NaN
# 2    1773.0           NaN           NaN       NaN            NaN
# 3    1773.0          33.0           0.0       0.0            0.0
# 4    1773.0           NaN           NaN       NaN            NaN
#
#    LateAircraftDelay  DivAirportLandings
# 0                NaN                 0.0
# 1                NaN                 0.0
# 2                NaN                 0.0
# 3                0.0                 0.0
# 4                NaN                 0.0
#
# [5 rows x 26 columns]

# %%
#Get Flight Number as a combination of Carrier code and individual flight number. E.g 'AA' and '346' becom 'AA346'
merged_df['FlightNumber'] = merged_df['UniqueCarrier'] + merged_df['FlightNum'].astype('str')

# %%
merged_df.drop(columns = 'FlightNum', inplace = True)
merged_df.head(3)
# Out:
#    Month  DayofMonth  DayOfWeek UniqueCarrier Origin Dest  DepTime  DepDelay  \
# 0      1          17          2            AA    CLT  PHX   1616.0      -3.0
# 1      1          18          3            AA    CLT  PHX   1614.0      -5.0
# 2      1          19          4            AA    CLT  PHX   1611.0      -8.0
#
#    TaxiOut  WheelsOff      ...       AirTime  Flights  Distance  CarrierDelay  \
# 0     17.0     1633.0      ...         244.0      1.0    1773.0           NaN
# 1     13.0     1627.0      ...         228.0      1.0    1773.0           NaN
# 2     17.0     1628.0      ...         236.0      1.0    1773.0           NaN
#
#    WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 0           NaN       NaN            NaN                NaN
# 1           NaN       NaN            NaN                NaN
# 2           NaN       NaN            NaN                NaN
#
#    DivAirportLandings  FlightNumber
# 0                 0.0         AA494
# 1                 0.0         AA494
# 2                 0.0         AA494
#
# [3 rows x 26 columns]

# %%
merged_df.drop(columns = 'DivAirportLandings', inplace = True)
merged_df.head(3)
# Out:
#    Month  DayofMonth  DayOfWeek UniqueCarrier Origin Dest  DepTime  DepDelay  \
# 0      1          17          2            AA    CLT  PHX   1616.0      -3.0
# 1      1          18          3            AA    CLT  PHX   1614.0      -5.0
# 2      1          19          4            AA    CLT  PHX   1611.0      -8.0
#
#    TaxiOut  WheelsOff      ...       Diverted  AirTime  Flights  Distance  \
# 0     17.0     1633.0      ...            0.0    244.0      1.0    1773.0
# 1     13.0     1627.0      ...            0.0    228.0      1.0    1773.0
# 2     17.0     1628.0      ...            0.0    236.0      1.0    1773.0
#
#    CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 0           NaN           NaN       NaN            NaN                NaN
# 1           NaN           NaN       NaN            NaN                NaN
# 2           NaN           NaN       NaN            NaN                NaN
#
#    FlightNumber
# 0         AA494
# 1         AA494
# 2         AA494
#
# [3 rows x 25 columns]

# %%
#Get Flights that have origins from JFK, ORD, DFW, MIA, LAX
subset_df = merged_df[(merged_df['Origin'] == 'JFK') | (merged_df['Origin'] == 'ORD') | (merged_df['Origin'] == 'DFW') | (merged_df['Origin'] == 'MIA') | (merged_df['Origin'] == 'LAX')]

# %%
#Sort dataframe by month and by day of month
df_sorted_by_month_day = subset_df.sort_values(['Month', 'DayofMonth'], ascending = [True, True])

# %%
sns.countplot(df_sorted_by_month_day['UniqueCarrier'])

# %%
#Drop wheelsoff and wheelson columns as this amounts to the same thing as the Airtime Column
df_sorted_by_month_day.drop(columns = ['WheelsOff', 'WheelsOn'], inplace = True)

# %%
#Get final dataframe to be merged and used for analysis with the 'DepDelay' column as the target
final_df = df_sorted_by_month_day[['Month', 'DayofMonth', 'Origin', 'Dest', 'DepTime','DepDelay', 'ArrTime', 'ArrDelay', 'AirTime', 'Flights', 'Distance', 'FlightNumber']]

# %%
#Get Scheduled Departure time from Actual Departure time and Departure Delay time
final_df['SchedDepartTime'] = final_df['DepTime'] - final_df['DepDelay']
# Out:
# /Users/shachiakyaagba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df.isnull().sum()
# Out:
# Month              0
# DayofMonth         0
# Origin             0
# Dest               0
# DepTime            0
# DepDelay           0
# ArrTime            0
# ArrDelay           0
# AirTime            0
# Flights            0
# Distance           0
# FlightNumber       0
# SchedDepartTime    0
# dtype: int64

# %%
#Get rid of all nan values
final_df.dropna(axis = 0, inplace = True)
# Out:
# /Users/shachiakyaagba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df['hour'] = final_df['DepTime'] // 100
# Out:
# /Users/shachiakyaagba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df.head()
# Out:
#      Month  DayofMonth Origin Dest  DepTime  DepDelay  ArrTime  ArrDelay  \
# 104      1           1    DFW  SFO   2205.0      -3.0     23.0      25.0
# 169      1           1    LAX  OMA   1813.0      -7.0   2307.0     -31.0
# 297      1           1    LAX  CMH    936.0      -9.0   1653.0     -14.0
# 350      1           1    DFW  CLE   1059.0      -6.0   1416.0     -19.0
# 360      1           1    DFW  PHX   2034.0      14.0   2210.0      12.0
#
#      AirTime  Flights  Distance FlightNumber  SchedDepartTime  hour
# 104    223.0      1.0    1464.0        AA499           2208.0  22.0
# 169    152.0      1.0    1330.0        AA501           1820.0  18.0
# 297    223.0      1.0    1995.0        AA508            945.0   9.0
# 350    114.0      1.0    1021.0        AA511           1065.0  10.0
# 360    128.0      1.0     868.0        AA513           2020.0  20.0

# %%
final_df.drop(columns = 'Flights', inplace = True)
# Out:
# /Users/shachiakyaagba/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
final_df[final_df['DepTime']==2359]
# Out:
#         Month  DayofMonth Origin Dest  DepTime  DepDelay  ArrTime  ArrDelay  \
# 253792      1           1    JFK  BQN   2359.0       0.0    422.0     -21.0
# 64229       1           2    DFW  LAS   2359.0      62.0    117.0      87.0
# 53211       1           5    DFW  DEN   2359.0     314.0    103.0     301.0
# 64982       1           7    ORD  DFW   2359.0     204.0    203.0     176.0
# 88169       1           7    LAX  IAH   2359.0       0.0    505.0      -8.0
# 150650      1          11    JFK  SJU   2359.0       0.0    426.0     -19.0
# 146239      1          12    LAX  ANC   2359.0      14.0    429.0      -1.0
# 150651      1          12    JFK  SJU   2359.0       0.0    433.0     -12.0
# 252607      1          14    JFK  PSE   2359.0       8.0    512.0      33.0
# 120         1          18    DFW  SFO   2359.0     114.0    137.0      98.0
# 36543       1          21    LAX  ATL   2359.0      24.0    656.0      13.0
# 253808      1          21    JFK  BQN   2359.0       0.0    429.0     -16.0
# 328066      1          22    LAX  JFK   2359.0       4.0    802.0     -29.0
# 82322       1          25    LAX  IAH   2359.0       0.0    503.0     -10.0
# 187409      1          29    LAX  IAH   2359.0       0.0    554.0      41.0
# 18797       1          30    LAX  JFK   2359.0       0.0    805.0     -12.0
# 220073      2           2    LAX  IAH   2359.0       0.0    506.0      -7.0
# 108700      2          10    JFK  ROC   2359.0      78.0    118.0      75.0
# 227320      2          16    LAX  IAH   2359.0       0.0    527.0      14.0
# 113527      2          20    JFK  BQN   2359.0       0.0    410.0     -35.0
# 165303      2          22    LAX  DTW   2359.0       2.0    705.0     -28.0
# 113530      2          23    JFK  BQN   2359.0       0.0    445.0       0.0
# 198006      2          27    LAX  IAH   2359.0       0.0    448.0     -25.0
# 262331      3           6    LAX  DTW   2359.0       2.0    702.0     -31.0
# 225511      3           7    LAX  JFK   2359.0       9.0    748.0     -38.0
# 355361      3           7    JFK  BQN   2359.0       0.0    432.0     -12.0
# 285335      3          12    LAX  ATL   2359.0      89.0    727.0      98.0
# 72444       3          14    LAX  IAH   2359.0       0.0    515.0       2.0
# 26756       3          19    MIA  DFW   2359.0      10.0    140.0     -25.0
# 96035       3          21    LAX  IAD   2359.0      34.0    725.0       6.0
# ...       ...         ...    ...  ...      ...       ...      ...       ...
# 147076      9           8    LAX  ORD   2359.0      14.0    559.0       8.0
# 445949      9           9    JFK  BQN   2359.0       0.0    400.0      12.0
# 449356      9          13    JFK  SJU   2359.0       0.0    333.0     -14.0
# 449918      9          14    JFK  BQN   2359.0       0.0    334.0     -14.0
# 152728      9          19    DFW  TUL   2359.0     227.0     59.0     223.0
# 15661      10           1    LAX  ORD   2359.0       0.0    538.0     -21.0
# 80020      10           9    JFK  MIA   2359.0     270.0    228.0     210.0
# 453102     10          24    JFK  ROC   2359.0      79.0    140.0      95.0
# 116700     10          25    LAX  SEA   2359.0      24.0    228.0      13.0
# 331641     11           8    DFW  LAS   2359.0      89.0     44.0      74.0
# 40609      11          11    LAX  ORD   2359.0       0.0    538.0     -17.0
# 149338     11          13    LAX  ORD   2359.0       9.0    547.0      -8.0
# 109452     11          18    LAX  SFO   2359.0      24.0    139.0      41.0
# 291748     11          21    LAX  ANC   2359.0       4.0    406.0     -39.0
# 145904     11          27    LAX  JFK   2359.0       9.0    833.0      15.0
# 457559     12           4    LAX  EWR   2359.0      24.0    754.0       9.0
# 368027     12           5    JFK  PWM   2359.0      77.0     57.0      59.0
# 371765     12           9    JFK  BUF   2359.0      74.0    112.0      63.0
# 59516      12          11    LAX  JFK   2359.0       9.0    827.0       9.0
# 374050     12          12    JFK  SJU   2359.0       0.0    458.0      12.0
# 62848      12          14    LAX  ORD   2359.0       9.0    632.0      37.0
# 62852      12          18    LAX  ORD   2359.0       0.0    607.0       1.0
# 382928     12          23    JFK  SJU   2359.0       0.0    438.0      -5.0
# 51779      12          24    LAX  SAT   2359.0       0.0    447.0     -13.0
# 62858      12          24    LAX  ORD   2359.0       0.0    546.0     -20.0
# 217555     12          24    LAX  ATL   2359.0       0.0    700.0      -5.0
# 383516     12          24    JFK  BQN   2359.0       0.0    449.0       4.0
# 62859      12          25    LAX  ORD   2359.0       0.0    536.0     -30.0
# 386279     12          27    JFK  SJU   2359.0       0.0    433.0     -10.0
# 150108     12          30    LAX  ANC   2359.0       4.0    448.0      -5.0
#
#         AirTime  Distance FlightNumber  SchedDepartTime  hour
# 253792    181.0    1576.0        B6839           2359.0  23.0
# 64229     179.0    1055.0        NK817           2297.0  23.0
# 53211      93.0     641.0        F9131           2045.0  23.0
# 64982     105.0     802.0        NK903           2155.0  23.0
# 88169     157.0    1379.0        UA717           2359.0  23.0
# 150650    188.0    1598.0       B61503           2359.0  23.0
# 146239    310.0    2345.0        AS175           2345.0  23.0
# 150651    190.0    1598.0       B61503           2359.0  23.0
# 252607    197.0    1617.0        B6745           2351.0  23.0
# 120       196.0    1464.0        AA499           2245.0  23.0
# 36543     205.0    1946.0       DL2840           2335.0  23.0
# 253808    189.0    1576.0        B6839           2359.0  23.0
# 328066    274.0    2475.0         AA30           2355.0  23.0
# 82322     149.0    1379.0        UA717           2359.0  23.0
# 187409    171.0    1379.0        UA717           2359.0  23.0
# 18797     287.0    2475.0       B62024           2359.0  23.0
# 220073    152.0    1379.0        UA717           2359.0  23.0
# 108700     59.0     264.0        B6486           2281.0  23.0
# 227320    174.0    1379.0        UA717           2359.0  23.0
# 113527    172.0    1576.0        B6839           2359.0  23.0
# 165303    216.0    1979.0       DL1352           2357.0  23.0
# 113530    205.0    1576.0        B6839           2359.0  23.0
# 198006    152.0    1379.0        UA717           2359.0  23.0
# 262331    219.0    1979.0       DL1352           2357.0  23.0
# 225511    266.0    2475.0         AA30           2350.0  23.0
# 355361    187.0    1576.0        B6839           2359.0  23.0
# 285335    232.0    1947.0       DL1354           2270.0  23.0
# 72444     161.0    1379.0        UA717           2359.0  23.0
# 26756     142.0    1121.0       AA2663           2349.0  23.0
# 96035     244.0    2288.0        UA411           2325.0  23.0
# ...         ...       ...          ...              ...   ...
# 147076    211.0    1744.0        AA219           2345.0  23.0
# 445949    223.0    1576.0        B6839           2359.0  23.0
# 449356    193.0    1598.0       B61503           2359.0  23.0
# 449918    192.0    1576.0        B6839           2359.0  23.0
# 152728     43.0     237.0       AA1464           2132.0  23.0
# 15661     194.0    1744.0       UA1617           2359.0  23.0
# 80020     131.0    1089.0       DL2951           2089.0  23.0
# 453102     43.0     264.0        B6486           2280.0  23.0
# 116700    127.0     954.0        AS287           2335.0  23.0
# 331641    144.0    1055.0        AA576           2270.0  23.0
# 40609     194.0    1744.0       UA1608           2359.0  23.0
# 149338    198.0    1744.0        AA219           2350.0  23.0
# 109452     59.0     337.0       VX1979           2335.0  23.0
# 291748    276.0    2345.0        AS193           2355.0  23.0
# 145904    293.0    2475.0         AA30           2350.0  23.0
# 457559    260.0    2454.0       UA1882           2335.0  23.0
# 368027     38.0     273.0        B6108           2282.0  23.0
# 371765     53.0     301.0       B62002           2285.0  23.0
# 59516     302.0    2475.0         AA30           2350.0  23.0
# 374050    217.0    1598.0       B61503           2359.0  23.0
# 62848     236.0    1744.0        AA219           2350.0  23.0
# 62852     213.0    1744.0        AA219           2359.0  23.0
# 382928    196.0    1598.0       B61503           2359.0  23.0
# 51779     146.0    1211.0       OO5673           2359.0  23.0
# 62858     194.0    1744.0        AA219           2359.0  23.0
# 217555    207.0    1947.0       DL1354           2359.0  23.0
# 383516    203.0    1576.0        B6839           2359.0  23.0
# 62859     189.0    1744.0        AA219           2359.0  23.0
# 386279    191.0    1598.0       B61503           2359.0  23.0
# 150108    309.0    2345.0        AS193           2355.0  23.0
#
# [146 rows x 13 columns]
